# %%
from impedance import preprocessing
import numpy as np
import pandas as pd

# %%
df=np.genfromtxt("EIS_state_V_45C01.txt",delimiter="\t")
fr,Z = preprocessing.readCSV('./exampleData.csv')
R0_45c01=[]
R1_45c01 = []
C1_45c01 = []
R2_45c01 = []
C2_45c01 = []
R3_45c01 = []
Wo1_0_45c01 = []
Wo1_1_45c01 = []
C3_45c01=[]

# %%
n=299
for k in range(1,n+1):
    freq=df[:,2][df[:,1]==1]
    real=df[:,3][df[:,1]==k]
    img=(df[:,4][df[:,1]==k])*1j


    for i in range(np.size(freq)):

        Z[i]=real[i]-img[i]
    Z=Z[:60]
    from impedance.models.circuits import Randles,CustomCircuit as cc
    circuit = 'R0-p(R1,C1)-p(R2,C2)-p(R3-Wo1,C3)'
    initial_guess = [.01, .01, 100, .01, 100,.01, .05, 100, 1]
    circuit=cc(circuit=circuit,initial_guess=initial_guess)
    circuit=circuit.fit(freq,Z)
    
    R0_45c01.append(circuit.parameters_[0])
    R1_45c01.append(circuit.parameters_[1])
    C1_45c01.append(circuit.parameters_[2])
    R2_45c01.append(circuit.parameters_[3])
    C2_45c01.append(circuit.parameters_[4])
    R3_45c01.append(circuit.parameters_[5])
    Wo1_0_45c01.append(circuit.parameters_[6])
    Wo1_1_45c01.append(circuit.parameters_[7])
    C3_45c01.append(circuit.parameters_[8])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-69aab2f05b31> in <module>
#      14     initial_guess = [.01, .01, 100, .01, 100,.01, .05, 100, 1]
#      15     circuit=cc(circuit=circuit,initial_guess=initial_guess)
# ---> 16     circuit=circuit.fit(freq,Z)
#      17
#      18     R0_45c01.append(circuit.parameters_[0])
#
# ~/anaconda3/lib/python3.7/site-packages/impedance/models/circuits/circuits.py in fit(self, frequencies, impedance, method, bounds)
#     105                                            self.circuit, self.initial_guess,
#     106                                            self.constants, method=method,
# --> 107                                            bounds=bounds)
#     108             self.parameters_ = parameters
#     109             if conf is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/impedance/models/circuits/fitting.py in circuit_fit(frequencies, impedances, circuit, initial_guess, constants, method, bounds, bootstrap)
#      91                            np.hstack([Z.real, Z.imag]), p0=initial_guess,
#      92                            method=method, bounds=bounds, maxfev=100000,
# ---> 93                            ftol=1E-13)
#      94
#      95     perror = np.sqrt(np.diag(pcov))
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     776
#     777         if not res.success:
# --> 778             raise RuntimeError("Optimal parameters not found: " + res.message)
#     779
#     780         ysize = len(res.fun)
#
# RuntimeError: Optimal parameters not found: The maximum number of function evaluations is exceeded.

# %%
df=np.genfromtxt("EIS_state_V_35C02.txt",delimiter="\t")
fr,Z = preprocessing.readCSV('./exampleData.csv')
R0_35c02=[]
R1_35c02 = []
C1_35c02 = []
R2_35c02 = []
C2_35c02 = []
R3_35c02 = []
Wo1_0_35c02 = []
Wo1_1_35c02 = []
C3_35c02=[]

# %%
n=318
for k in range(1,n+1):
    freq=df[:,2][df[:,1]==1]
    real=df[:,3][df[:,1]==k]
    img=(df[:,4][df[:,1]==k])*1j


    for i in range(np.size(freq)):

        Z[i]=real[i]-img[i]
    Z=Z[:60]
    from impedance.models.circuits import Randles,CustomCircuit as cc
    circuit = 'R0-p(R1,C1)-p(R2,C2)-p(R3-Wo1,C3)'
    initial_guess = [.01, .01, 100, .01, 100,.01, .05, 100, 1]
    circuit=cc(circuit=circuit,initial_guess=initial_guess)
    circuit=circuit.fit(freq,Z)
    
    R0_35c02.append(circuit.parameters_[0])
    R1_35c02.append(circuit.parameters_[1])
    C1_35c02.append(circuit.parameters_[2])
    R2_35c02.append(circuit.parameters_[3])
    C2_35c02.append(circuit.parameters_[4])
    R3_35c02.append(circuit.parameters_[5])
    Wo1_0_35c02.append(circuit.parameters_[6])
    Wo1_1_35c02.append(circuit.parameters_[7])
    C3_35c02.append(circuit.parameters_[8])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-6655a2323b27> in <module>
#      14     initial_guess = [.01, .01, 100, .01, 100,.01, .05, 100, 1]
#      15     circuit=cc(circuit=circuit,initial_guess=initial_guess)
# ---> 16     circuit=circuit.fit(freq,Z)
#      17
#      18     R0_35c02.append(circuit.parameters_[0])
#
# ~/anaconda3/lib/python3.7/site-packages/impedance/models/circuits/circuits.py in fit(self, frequencies, impedance, method, bounds)
#     105                                            self.circuit, self.initial_guess,
#     106                                            self.constants, method=method,
# --> 107                                            bounds=bounds)
#     108             self.parameters_ = parameters
#     109             if conf is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/impedance/models/circuits/fitting.py in circuit_fit(frequencies, impedances, circuit, initial_guess, constants, method, bounds, bootstrap)
#      91                            np.hstack([Z.real, Z.imag]), p0=initial_guess,
#      92                            method=method, bounds=bounds, maxfev=100000,
# ---> 93                            ftol=1E-13)
#      94
#      95     perror = np.sqrt(np.diag(pcov))
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     776
#     777         if not res.success:
# --> 778             raise RuntimeError("Optimal parameters not found: " + res.message)
#     779
#     780         ysize = len(res.fun)
#
# RuntimeError: Optimal parameters not found: The maximum number of function evaluations is exceeded.

# %%
np.shape(R0_45c01)
# Out:
# (92,)

# %%
para_45c01=pd.DataFrame ({
"R0_45c01":R0_45c01,
"R1_45c01" :R2_45c01,
"C1_45c01" : C1_45c01,
"R2_45c01" : R2_45c01,
"C2_45c01" : C2_45c01,
"R3_45c01" : R3_45c01,
"Wo1_0_45c01":Wo1_0_45c01,
"Wo1_1_45c01":Wo1_1_45c01,
"C3_45c01":C3_45c01,


                   })

# %%
para_45c01.to_csv("para_3RC_45c01.csv")

# %%
para_35c02=pd.DataFrame ({
"R0_35c02":R0_35c02,
"R1_35c02" :R2_35c02,
"C1_35c02" : C1_35c02,
"R2_35c02" : R2_35c02,
"C2_35c02" : C2_35c02,
"R3_35c02" : R3_35c02,
"Wo1_0_35c02":Wo1_0_35c02,
"Wo1_1_35c02":Wo1_1_35c02,
"C3_35c02":C3_35c02
                   })

# %%
para_35c02.to_csv("para_3RC_35c02.csv")

# %%
df=np.genfromtxt("EIS_state_III_25C01.txt",delimiter="\t")
fr,Z = preprocessing.readCSV('./exampleData.csv')
R0_25c01_3=[]
R1_25c01_3= []
C1_25c01_3= []
R2_25c01_3 = []
C2_25c01_3= []
# R3_25c01 = []
Wo1_0_25c01_3 = []
Wo1_1_25c01_3= []
# C3_25c01=[]

# %%
n=261
for k in range(1,n+1):
    freq=df[:,2][df[:,1]==1]
    real=df[:,3][df[:,1]==k]
    img=(df[:,4][df[:,1]==k])*1j


    for i in range(np.size(freq)):

        Z[i]=real[i]-img[i]
    Z=Z[:60]
    from impedance.models.circuits import Randles,CustomCircuit as cc
    circuit = 'R0-p(R1,C1)-p(R2-Wo1,C2)'
    initial_guess = [.01, .01, 100, .01, .05, 100, 1]
#     circuit = 'R0-p(R1,C1)-p(R2,C2)-p(R3-Wo1,C3)'
#     initial_guess = [.01, .01, 100, .01, 100,.01, .05, 100, 1]
    circuit=cc(circuit=circuit,initial_guess=initial_guess)
    circuit=circuit.fit(freq,Z)
    
    R0_25c01_3.append(circuit.parameters_[0])
    R1_25c01_3.append(circuit.parameters_[1])
    C1_25c01_3.append(circuit.parameters_[2])
    R2_25c01_3.append(circuit.parameters_[3])
    C2_25c01_3.append(circuit.parameters_[4])
#     R3_25c01.append(circuit.parameters_[5])
    Wo1_0_25c01_3.append(circuit.parameters_[5])
    Wo1_1_25c01_3.append(circuit.parameters_[6])
#     C3_25c01.append(circuit.parameters_[8])

# %%
c_I=pd.read_csv("para_2RC_25c01_state_I.csv")

# %%
c_III=pd.read_csv("para_2RC_25c01_state_III.csv")

# %%
c_V=pd.read_csv("para_2RC_25c01.csv")

# %%
import matplotlib.pyplot as plt
plt.plot(np.arange(1,161,1),c_I["R0_25c01"])
plt.plot(np.arange(1,161,1),c_III["R0_25c03"][:160])
plt.plot(np.arange(1,161,1),c_V["R0_25c01"][:160])
plt.legend(["State_I","State_III","State_V"])

plt.xlabel("Cycles")
plt.ylabel("R0")
plt.savefig(".png", format="png")
plt.show()
